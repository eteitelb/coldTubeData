# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
import datetime
import seaborn #Seaborn is a a stats plotting library that sits on matplotlib
from scipy.stats import ttest_ind
mpl.rcParams['font.family'] = 'Arial'
textsize=18

seaborn.set_style("white")
seaborn.set_style("ticks")
data = pd.read_csv('cleanDataSmall.csv', index_col=0, parse_dates=True)

# %%
x1 = pd.DataFrame(data[data['StudyID']==1]['CTComf2'])
y1 = pd.Series(data[data['StudyID']==1]['CTComf1'])
z1 = pd.Series(data[data['StudyID']==1]['WalkComf'])
a1 = pd.Series(data[data['StudyID']==1]['ShadeComf'])

x2 = pd.Series(data[data['StudyID']==2]['CTComf2'])
y2 = pd.Series(data[data['StudyID']==2]['CTComf1'])
z2 = pd.Series(data[data['StudyID']==2]['WalkComf'])
a2 = pd.Series(data[data['StudyID']==2]['ShadeComf'])

import statsmodels

# %%
textsize = 18
plt.figure(figsize=(7,4))
ax = seaborn.distplot(x1, bins = [-3,-2,-1,0,1,2,3, 4], kde_kws={"color": "k", "lw": 3,"alpha": 0}, label = 'On group: 27% > 0; $\mu$ = -0.05; $\sigma$ = 0.81', color = 'k')
#seaborn.distplot(y1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0}, ax=ax)
#seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0}, ax=ax)

seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3, 4], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step","linewidth": 3,"alpha": 1, "color": "k"}, label = 'Off Group: 53% > 0; $\mu$ = 0.53; $\sigma$ = 0.74')
#seaborn.distplot(y2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "g"}, ax=ax)
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"}, ax=ax)
plt.ylim(0,1)
plt.xlim(-3,4)
plt.title('$p<0.02$', size = textsize)
plt.xlabel('', size = textsize)
#plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("10minCT.pdf",format='pdf')

#p<0.02

# %%
plt.figure(figsize=(7,4))
#ax = seaborn.distplot(x1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})
#seaborn.distplot(y1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0}, ax=ax)
ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3,4], kde_kws={"color": "k", "lw": 3,"alpha": 0}, label = 'On group: 97% > 0; $\mu$ = 1.73; $\sigma$ = 0.80', color = 'k')

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
#seaborn.distplot(y2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "g"}, ax=ax)
seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3, 4], kde=True, rug_kws={"color": "r"}, kde_kws={'bw':0.1,"color": "k","lw": 3,"alpha": 0}, hist_kws={"histtype": "step", "linewidth": 3, "alpha": 1, "color": "k"}, label = 'Off group:: 100% > 0; $\mu$ = 2.0; $\sigma$ = 0.65')
plt.ylim(0,1)
plt.xlim(-3,4)
plt.title('$p<0.25$', size = textsize)
plt.xlabel('', size = textsize)
#plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("10minWalking.pdf",format='pdf')

#, "label": "$p<0.25$"

# %%
plt.figure(figsize=(7,4))
#ax = seaborn.distplot(x1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})
ax2 = seaborn.distplot(y1, bins = [-3,-2,-1,0,1,2,3, 4], kde_kws={"color": "k", "lw": 3,"alpha": 0}, color = 'k', label = 'On group: 46% > 0; $\mu$ = 0.30; $\sigma$ = 1.02')
#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
seaborn.distplot(y2, bins = [-3,-2,-1,0,1,2,3, 4], rug_kws={"color": "g"}, kde_kws={'bw':0.1,"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "k"}, label = 'Off group: 80% > 0; $\mu$ = 1.07; $\sigma$ = 1.03')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
plt.ylim(0,1)
plt.xlim(-3,4)
plt.title('$p<0.02$', size = textsize)
plt.xlabel('', size = textsize)
#plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("1minCT.pdf",format='pdf')

#, "label": "$p<0.02$"

# %%
plt.figure(figsize=(7,4))
#ax = seaborn.distplot(x1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})
ax2 = seaborn.distplot(a1, bins = [-3,-2,-1,0,1,2,3, 4], kde_kws={"color": "k", "lw": 3,"alpha": 0}, color = 'k', label = 'On group: 32% > 0; $\mu$ = 0.41; $\sigma$ = 0.72')
#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
seaborn.distplot(a2, bins = [-3,-2,-1,0,1,2,3, 4], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "k"}, label = 'Off group: 47% > 0; $\mu$ = 0.60; $\sigma$ = 0.74')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
plt.ylim(0,1)
plt.xlim(-3,4)
plt.title('$p<0.39$', size = textsize)
plt.xlabel('', size = textsize)
#plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("InitialStateCT.pdf",format='pdf')

#"label": "$p<0.39$"

# %%
plt.figure(figsize=(10,8))


x1 = pd.DataFrame(data[data['StudyID']>0]['Watts'])
x1 = x1.dropna()
#print(x1)

x2 = pd.DataFrame(data[data['CTComf2']<0]['Watts'])
x2 = x2.dropna()

x3 = pd.DataFrame(data[data['CTComf2']==0]['Watts'])
x3 = x3.dropna()

x4 = pd.DataFrame(data[data['CTComf2']>0]['Watts'])
x4 = x4.dropna()




#seaborn.distplot(x1, color = 'k')
seaborn.distplot(x2, kde_kws={"color": "b", "lw": 3,"alpha": 1, "label": "Cool, Vote < 0"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
seaborn.distplot(x3, kde_kws={"color": "g", "lw": 3,"alpha": 1, "label": "Neutral, Vote = 0"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
seaborn.distplot(x4, kde_kws={"color": "r", "lw": 3,"alpha": 1, "label": "Warm, Vote > 0"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
#seaborn.distplot(x1, kde_kws={"color": "k", "lw": 3,"alpha": 1, "label": "All Data, with bars"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})


#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
#seaborn.distplot(a2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "label": "$p<0.15$", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "m"}, label = 'Control: 60% > 0; $\mu$ = 0.70; $\sigma$ = 0.70')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
#plt.ylim(0,0.03)
#plt.xlim(-3,3)
#plt.title('Ambient Conditions as Predictors', size = textsize)

plt.fill_between([65,75], 0, 1, alpha=0.1, color='k', label = "Metabolic Rate Range")
plt.ylim(0,0.03)
plt.xlabel('Heat Loss Rate ($W$ $m^{-2}$)', size = textsize)
plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize-4)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("HeatHist2.pdf",format='pdf')
#ttest_ind(b1, b2)

# %%
#dataExp = data[data['StudyID']==1]
plt.figure(figsize=(10,8))
x1 = pd.DataFrame(data[data['StudyID']>0]['Operative Temperature'])
x1 = x1.dropna()
#print(x1)

x2 = pd.DataFrame(data[data['CTAirSat1']<4]['Operative Temperature'])
x2 = x2.dropna()

x3 = pd.DataFrame(data[data['CTAirSat1']==4]['Operative Temperature'])
x3 = x3.dropna()

x4 = pd.DataFrame(data[data['CTAirSat1']>4]['Operative Temperature'])
x4 = x4.dropna()
#b2 = pd.DataFrame(B1_ALL[B1_ALL['Clo']>0.5]['CTComf1'])






#seaborn.distplot(x1, color = 'k')
#seaborn.distplot(x1, kde_kws={"color": "k", "lw": 3,"alpha": 1,"label": "All Data, with bars"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
#seaborn.distplot(x3, kde_kws={"color": "g", "lw": 3,"alpha": 1}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0}, label = '32% > 0; $\mu$ = 0.41; $\sigma$ = 0.72')
seaborn.distplot(x4, kde_kws={"color": "b", "lw": 3,"alpha": 1,"label": "Satisfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
seaborn.distplot(x2, kde_kws={"color": "r", "lw": 3,"alpha": 1,"label": "Dissatsfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})


#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
#seaborn.distplot(a2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "label": "$p<0.15$", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "m"}, label = 'Control: 60% > 0; $\mu$ = 0.70; $\sigma$ = 0.70')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
#plt.ylim(0,0.035)
#plt.xlim(-3,3)
#plt.title('Ambient Conditions as Predictors', size = textsize)
#plt.fill_between([65,75], 0, 1, alpha=0.1, color='k', label = "Metabolic Rate Range")
plt.xlabel('Operative Temperature', size = textsize)
plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("SatHist3.pdf",format='pdf')
#ttest_ind(b1, b2)

# %%
#dataExp = data[data['StudyID']==1]
plt.figure(figsize=(10,8))
x1 = pd.DataFrame(data[data['StudyID']>0]['Mean Radiant Temperature'])
x1 = x1.dropna()
#print(x1)

x2 = pd.DataFrame(data[data['CTAirSat1']<4]['Mean Radiant Temperature'])
x2 = x2.dropna()

x3 = pd.DataFrame(data[data['CTAirSat1']==4]['Mean Radiant Temperature'])
x3 = x3.dropna()

x4 = pd.DataFrame(data[data['CTAirSat1']>4]['Mean Radiant Temperature'])
x4 = x4.dropna()
#b2 = pd.DataFrame(B1_ALL[B1_ALL['Clo']>0.5]['CTComf1'])






#seaborn.distplot(x1, color = 'k')
#seaborn.distplot(x1, kde_kws={"color": "k", "lw": 3,"alpha": 1,"label": "All Data, with bars"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
#seaborn.distplot(x3, kde_kws={"color": "g", "lw": 3,"alpha": 1}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0}, label = '32% > 0; $\mu$ = 0.41; $\sigma$ = 0.72')
seaborn.distplot(x4, kde_kws={"color": "b", "lw": 3,"alpha": 1,"label": "Satisfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
seaborn.distplot(x2, kde_kws={"color": "r", "lw": 3,"alpha": 1,"label": "Dissatsfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})


#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
#seaborn.distplot(a2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "label": "$p<0.15$", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "m"}, label = 'Control: 60% > 0; $\mu$ = 0.70; $\sigma$ = 0.70')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
#plt.ylim(0,0.035)
#plt.xlim(-3,3)
#plt.title('Ambient Conditions as Predictors', size = textsize)
#plt.fill_between([65,75], 0, 1, alpha=0.1, color='k', label = "Metabolic Rate Range")
plt.xlabel('Mean Radiant Temperature (C)', size = textsize)
plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("SatHist4.pdf",format='pdf')
#ttest_ind(b1, b2)

# %%
#dataExp = data[data['StudyID']==1]
plt.figure(figsize=(10,8))
x1 = pd.DataFrame(data[data['StudyID']>0]['Watts'])
x1 = x1.dropna()
#print(x1)

x2 = pd.DataFrame(data[data['CTAirSat1']<4]['Watts'])
x2 = x2.dropna()

x3 = pd.DataFrame(data[data['CTAirSat1']==4]['Radiant'])
x3 = x3.dropna()

x4 = pd.DataFrame(data[data['CTAirSat1']>4]['Watts'])
x4 = x4.dropna()
#b2 = pd.DataFrame(B1_ALL[B1_ALL['Clo']>0.5]['CTComf1'])






#seaborn.distplot(x1, color = 'k')
#seaborn.distplot(x1, kde_kws={"color": "k", "lw": 3,"alpha": 1,"label": "All Data, with bars"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
#seaborn.distplot(x3, kde_kws={"color": "g", "lw": 3,"alpha": 1}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0}, label = '32% > 0; $\mu$ = 0.41; $\sigma$ = 0.72')
seaborn.distplot(x4, kde_kws={"color": "b", "lw": 3,"alpha": 1,"label": "Satisfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})
seaborn.distplot(x2, kde_kws={"color": "r", "lw": 3,"alpha": 1,"label": "Dissatsfied"}, hist_kws={"histtype": "step", "linewidth": 3,"alpha": 0})


#ax1 = seaborn.distplot(z1, bins = [-3,-2,-1,0,1,2,3], kde_kws={"color": "k", "lw": 3, "label": "KDE","alpha": 0})

#seaborn.distplot(x2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "b"}, ax=ax)
#seaborn.distplot(a2, bins = [-3,-2,-1,0,1,2,3], rug_kws={"color": "g"}, kde_kws={"color": "k", "label": "$p<0.15$", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "m"}, label = 'Control: 60% > 0; $\mu$ = 0.70; $\sigma$ = 0.70')
#seaborn.distplot(z2, bins = [-3,-2,-1,0,1,2,3], kde = True, rug_kws={"color": "g"}, kde_kws={"color": "k", "lw": 3,"alpha": 0},hist_kws={"histtype": "step", "linewidth": 3,"alpha": 1, "color": "r"})
plt.ylim(0,0.035)
#plt.xlim(-3,3)
#plt.title('Ambient Conditions as Predictors', size = textsize)
plt.fill_between([65,75], 0, 1, alpha=0.1, color='k', label = "Metabolic Rate Range")
plt.xlabel('Heat Loss Rate ($W$ $m^{-2}$)', size = textsize)
plt.ylabel('% Observations', size = textsize)
plt.legend(loc = 2, fontsize = textsize)
plt.tick_params(axis='both', labelsize=textsize)
#plt.savefig("SatHist2.pdf",format='pdf')
#ttest_ind(b1, b2)

# %%
temperature = np.arange(5, 40, 0.1)
a=17.08
b=234.18
saturation = 1000*0.62198*np.exp(77.345+0.0057*(temperature+273.15)-7235/(temperature+273.15))/(101325*np.power((temperature+273.15),8.2)-np.exp(77.345+0.0057*(temperature+273.15)-7235/(temperature+273.15)))

temp_air_init = np.arange(10, 35, .5) 
RH_psy_init = np.arange(0,100,1)/100

temp_air_plot = np.tile(np.array(temp_air_init),(len(RH_psy_init),1)).transpose()
RH_psy_plot = np.tile(np.array(RH_psy_init),(len(temp_air_init),1))

temp_skin_plot = temp_air_plot*.3812+22.406
P_sat_skin_psy_plot = np.power(2.718,(77.3450+0.0057*(temp_skin_plot+273.15)-7235/(temp_skin_plot+273.15)))/(np.power((temp_skin_plot+273.15),8.2))/1000
psy_sat_plot = 1000*0.62198*np.exp(77.345+0.0057*(temp_air_plot+273.15)-7235/(temp_air_plot+273.15))/(101325*np.power((temp_air_plot+273.15),8.2)-np.exp(77.345+0.0057*(temp_air_plot+273.15)-7235/(temp_air_plot+273.15)))*RH_psy_plot
P_sat_air_psy_plot = np.power(2.718,(77.3450+0.0057*(temp_air_plot+273.15)-7235/(temp_air_plot+273.15)))/(np.power((temp_air_plot+273.15),8.2))/1000*RH_psy_plot

v_air = 0.26
h_c_forced_psy = 10.1*np.power(v_air,0.61)
Q_conv_forced_psy = h_c_forced_psy*(temp_skin_plot-temp_air_plot)   
h_e_forced_psy = h_c_forced_psy*16.5

MR = 1.2
MR= MR*58.1666666

w=0.06
E = 0.98
o = 0.00000005670367
Ar_Ad = 0.7

Q_evap_forced_psy = h_e_forced_psy*w*(P_sat_skin_psy_plot-P_sat_air_psy_plot)
T_MRT_forced_psy = np.power(np.power((temp_skin_plot+273.15),4)-((MR-Q_evap_forced_psy-Q_conv_forced_psy)/E/o/Ar_Ad),0.25)-273.15

# %%
plt.figure(figsize=(15,10))
X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.6
plt.plot(temperature, saturation, 'k-', linewidth = 1, alpha = 1)
plt.plot(temperature, saturation*.9, 'k-', linewidth = 1 , alpha = alph)
plt.plot(temperature, saturation*.8, 'k-', linewidth = 1, alpha = alph)
plt.plot(temperature, saturation*.7, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.6, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.5, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.4, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.3, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.2, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.1, 'k-', linewidth = 1,alpha = alph)

levels_contour = np.linspace(np.amin(T_MRT_forced_psy), np.amax(T_MRT_forced_psy), 15)
CS3=plt.contourf(Y, psy_sat_plot, T_MRT_forced_psy, cmap = 'jet', levels=levels_contour, alpha = 0.6)
CS = plt.contour(Y, psy_sat_plot, T_MRT_forced_psy, 20, colors='k', alpha = 1)
plt.clabel(CS, inline=3, fmt='%1.1f', fontsize=textsize)
cbar = plt.colorbar(CS3, orientation='vertical', format="%.1f")
plt.text(43.5,-1.75,"MRT $^\circ$C", size=textsize)

plt.text(35.5, 2.7, '10%',size=textsize)
plt.text(35.5, 6.8, '20%',size=textsize)
plt.text(35.5, 10.5, '30%',size=textsize)
plt.text(35.5, 14.1, '40%',size=textsize)
plt.text(35.5, 18, '50%',size=textsize)
plt.text(35.5, 21.5, '60%',size=textsize)
plt.text(35.5, 25.2, '70%',size=textsize)
plt.text(34, 28.1, '80%',size=textsize)
plt.text(30.8, 28.1, '90%',size=textsize)
plt.text(27, 27, '100%',size=textsize)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Humidity Ratio (g water/kg dry air)",size=textsize)

axes=plt.gca()
axes.set_ylim([0,28])


plt.tick_params(axis='both', labelsize=textsize)
cbar.ax.tick_params(labelsize=textsize) 

#plt.scatter(air_temp, dome_g, c=dome_MRT, cmap=cm.jet, norm = mpl.colors.Normalize(vmin=np.amin(T_MRT_psy),vmax=np.amax(T_MRT_psy)))

# %%
import matplotlib.cm as cm
air_temp_scat = np.array(data['Air'].values)
g_scat = np.array((data['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data['Air']+273.15)-7235/(data['Air']+273.15))/(101325*np.power((data['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data['Air']+273.15)-7235/(data['Air']+273.15)))).values)
#dome_wet_bulb = np.array(dome['wetbulb'])
MRT_scat = np.array(data['Ground Truth'])



plt.figure(figsize=(15,10))
X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.6
plt.plot(temperature, saturation, 'k-', linewidth = 1, alpha = 1)
plt.plot(temperature, saturation*.9, 'k-', linewidth = 1 , alpha = alph)
plt.plot(temperature, saturation*.8, 'k-', linewidth = 1, alpha = alph)
plt.plot(temperature, saturation*.7, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.6, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.5, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.4, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.3, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.2, 'k-', linewidth = 1,alpha = alph)
plt.plot(temperature, saturation*.1, 'k-', linewidth = 1,alpha = alph)

levels_contour = np.linspace(np.amin(T_MRT_forced_psy), np.amax(T_MRT_forced_psy), 15)
CS3=plt.contourf(Y, psy_sat_plot, T_MRT_forced_psy, cmap = 'jet', levels=levels_contour, alpha = 0.6)
CS = plt.contour(Y, psy_sat_plot, T_MRT_forced_psy, 20, colors='k', alpha = 1)
plt.clabel(CS, inline=3, fmt='%1.1f', fontsize=textsize)
cbar = plt.colorbar(CS3, orientation='vertical', format="%.1f")
plt.text(43.5,-1.75,"MRT $^\circ$C", size=textsize)

plt.text(35.5, 2.7, '10%',size=textsize)
plt.text(35.5, 6.8, '20%',size=textsize)
plt.text(35.5, 10.5, '30%',size=textsize)
plt.text(35.5, 14.1, '40%',size=textsize)
plt.text(35.5, 18, '50%',size=textsize)
plt.text(35.5, 21.5, '60%',size=textsize)
plt.text(35.5, 25.2, '70%',size=textsize)
plt.text(34, 28.1, '80%',size=textsize)
plt.text(30.8, 28.1, '90%',size=textsize)
plt.text(27, 27, '100%',size=textsize)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Humidity Ratio (g water/kg dry air)",size=textsize)

axes=plt.gca()
axes.set_ylim([0,28])


plt.tick_params(axis='both', labelsize=textsize)
cbar.ax.tick_params(labelsize=textsize) 
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)

#dome_wet_bulb = np.array(dome['wetbulb'])
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTComf2'])

#plt.scatter(air_temp_scat[(air_temp_scat-MRT_scat)>2], g_scat[(air_temp_scat-MRT_scat)>2], c=MRT_scat[(air_temp_scat-MRT_scat)>2], cmap=cm.jet, norm = mpl.colors.Normalize(vmin=np.amin(T_MRT_forced_psy),vmax=np.amax(T_MRT_forced_psy)))
CS3 = plt.scatter(air_temp_scat, g_scat, c=MRT_scat, marker = 's', s=50, cmap=cm.jet, norm = mpl.colors.Normalize(vmin=np.amin(T_MRT_forced_psy),vmax=np.amax(T_MRT_forced_psy)), edgecolors='k',alpha = 1)

#plt.scatter(air_temp_scat[(air_temp_scat-MRT_scat)>2], g_scat[(air_temp_scat-MRT_scat)>2])
plt.savefig("ColdTubeComfortPsychro.pdf",format='pdf')

# %%
#dataExp = data[data['StudyID']==2]
#air_temp_scat_warm = dataExp[dataExp['StudyID']>0]['Air']


g_scat_warm = data[data['StudyID']>0]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']>0]['Air']+273.15)-7235/(data[data['StudyID']>0]['Air']+273.15))/(101325*np.power((data[data['StudyID']>0]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']>0]['Air']+273.15)-7235/(data[data['StudyID']>0]['Air']+273.15)))

MRT_scat_warm = data[data['StudyID']>0]['Shade Globe']
MRT_scat_warm.fillna(data['Ground Truth'].mean(), inplace=True)
comfort_scat_warm = data[data['StudyID']>0]['CTAirSat1']
# Out:
# C:\Users\erict\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])


plt.figure(figsize=(8,7))
X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.05

plt.fill_between(temperature, saturation, saturation*0.9, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.8, saturation*0.7, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.6, saturation*0.5, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.4, saturation*0.3, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.2, saturation*0.1, alpha=alph, color='k')


alph = 0.6
CS4 = plt.scatter(air_temp_scat3, g_scat3, c=8-comfort_scat3, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS5 = plt.scatter(air_temp_scat2, g_scat2, c=8-comfort_scat2, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS3 = plt.scatter(air_temp_scat, g_scat, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

for i in range(len(MRT_scat)):
    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and g_scat[i] != np.nan and comfort_scat[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
        plt.plot([MRT_scat[i],air_temp_scat[i]],[0,g_scat[i]], c=colorVal,linestyle = ':', alpha = 0.6)
        
for i in range(len(MRT_scat3)):
    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and g_scat3[i] != np.nan and comfort_scat3[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
        plt.plot([MRT_scat3[i],air_temp_scat3[i]],[0,g_scat3[i]], c=colorVal,linestyle = ':', alpha = 0.6)
                          
for i in range(len(MRT_scat2)):
    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and g_scat2[i] != np.nan and comfort_scat2[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
        plt.plot([MRT_scat2[i],air_temp_scat2[i]],[0,g_scat2[i]], c=colorVal,linestyle = ':', alpha = 0.6)

        
#%RH lines
plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Temperature $^\circ$C", size=textsize)
plt.ylabel("Humidity Ratio (g water/kg dry air)",size=textsize)

thickness = 0.6
alph = 0.5
offset = .75

16.16745981
19.06545745

18.3832646255

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)

axes=plt.gca()


axes.set_ylim([0,28])
axes.set_xlim([20,35])



plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




plt.text(28, 23, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
plt.text(28, 21, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)
plt.text(25.1, 1, '$T_{MRT, on} \in$ [22.6, 26.5]',size=textsize-4)
plt.text(21,7,"$PPD_{on}=0.216$",size=textsize-4)
plt.text(31, 7,"$PPD_{off}=0.733$",size=textsize-4)

plt.text(27, 3.5, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25
alph = 1
plt.plot([28, 32.0], [19.5,19.5], c = 'k', alpha = alph)

plt.plot([28, 28], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([31.8, 31.8], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([32.0, 32.0], [19.5-height,19.5+height], c = 'k', alpha = alph)

height = 0.125
plt.plot([32.5, 32.5], [14.69860164,18.92509298], c = 'k', alpha = alph)
plt.plot([32.5-height, 32.5+height], [14.69860164,14.69860164], c = 'k', alpha = alph)
plt.plot([32.5-height, 32.5+height], [18.92509298,18.92509298], c = 'k', alpha = alph)

plt.text(32.75, 16.5, '$\%RH$',size=textsize-4)

plt.legend(loc = 2, fontsize = textsize-4)

plt.fill_between([22.6,26.5], [0,0], [0.25,0.25],  alpha=1, color='k')
plt.fill_between([29.8,33.2], [0,0], [0.25,0.25], alpha=1, color='k')

axes.get_yaxis().set_visible(False)

#plt.savefig("ColdTubeComfortCombined.pdf",format='pdf')

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])
operative = (air_temp_scat+MRT_scat)/2

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)
operative3 = (air_temp_scat3+MRT_scat3)/2

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])
operative2 = (air_temp_scat2+MRT_scat2)/2

plt.figure(figsize=(8,7))
X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.05

plt.fill_between(temperature, saturation, saturation*0.9, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.8, saturation*0.7, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.6, saturation*0.5, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.4, saturation*0.3, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.2, saturation*0.1, alpha=alph, color='k')


alph = 0.6
CS4 = plt.scatter(operative3, g_scat3, c=8-comfort_scat3, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS5 = plt.scatter(operative2, g_scat2, c=8-comfort_scat2, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS3 = plt.scatter(operative, g_scat, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

pointwidth = 0.2

for i in range(len(MRT_scat)):
    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and g_scat[i] != np.nan and comfort_scat[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
        plt.plot([air_temp_scat[i],operative[i]],[pointwidth,g_scat[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
        
for i in range(len(MRT_scat3)):
    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and g_scat3[i] != np.nan and comfort_scat3[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
        plt.plot([air_temp_scat3[i],operative3[i]],[pointwidth,g_scat3[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
                          
for i in range(len(MRT_scat2)):
    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and g_scat2[i] != np.nan and comfort_scat2[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
        plt.plot([air_temp_scat2[i],operative2[i]],[pointwidth,g_scat2[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)

        
#%RH lines
plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Temperature $^\circ$C", size=textsize)
plt.ylabel("Humidity Ratio (g water/kg dry air)",size=textsize)

thickness = 0.6
alph = 0.5
offset = .75

16.16745981
19.06545745

18.3832646255

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)

axes=plt.gca()


axes.set_ylim([0,28])
axes.set_xlim([20,35])



plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




plt.text(21, 25, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
plt.text(21, 23, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)
#plt.text(25.1, 1, '$T_{MRT, on} \in$ [22.6, 26.3]',size=textsize-4)
plt.text(21,20,"$PPD_{on}=0.216$",size=textsize-4)
plt.text(21, 18,"$PPD_{off}=0.733$",size=textsize-4)

plt.text(26, 21, '$T_{op, on} \in$ [25.4, 29.2]',size=textsize-4)
plt.text(29, 23, '$T_{op, off} \in$ [29.4, 32.6]',size=textsize-4)

#plt.text(27, 3.5, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25
alph = 1
plt.plot([25.42, 29.21], [19.5,19.5], c = 'k', alpha = alph)

plt.plot([25.42, 25.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([29.21, 29.21], [19.5-height,19.5+height], c = 'k', alpha = alph)


plt.plot([29.42, 32.63], [19.5,19.5], c = 'k', alpha = alph)

plt.plot([29.42, 29.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([32.63, 32.63], [19.5-height,19.5+height], c = 'k', alpha = alph)

height = 0.125
plt.plot([33, 33], [14.69860164,18.92509298], c = 'k', alpha = alph)
plt.plot([33-height, 33+height], [14.69860164,14.69860164], c = 'k', alpha = alph)
plt.plot([33-height, 33+height], [18.92509298,18.92509298], c = 'k', alpha = alph)

plt.text(33.25, 16.5, '$\%RH$',size=textsize-4)

plt.legend(loc = 3, fontsize = textsize-4)

#plt.fill_between([22.6,26.3], [0,0], [0.25,0.25],  alpha=1, color='k')
#plt.fill_between([29.8,33.2], [0,0], [0.25,0.25], alpha=1, color='k')

axes.get_yaxis().set_visible(False)

#plt.savefig("ColdTubeComfortOperative.pdf",format='pdf')

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
RH_scat = np.array((data[data['StudyID']==1]['Relative Humidity']))
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])
operative = (MRT_scat+(air_temp_scat*np.power(10*air_speed,0.5)))/(1+np.power(10*air_speed,0.5))
operative_1 = operative

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
RH_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']))
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)
air_speed3 = np.array(data[data['StudyID']==2]['Air Speed'].values)
operative3 = (MRT_scat3+(air_temp_scat3*np.power(10*air_speed3,0.5)))/(1+np.power(10*air_speed3,0.5))
operative3_3 = operative3

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])
air_speed2 = np.array([0.5573, 0.502567, 0.277833, 0.2326, 0.194533, 0.3393, 0.272167, 0.252333, 0.366533])
operative2 = (air_temp_scat2+MRT_scat2)/2
operative2 = (MRT_scat2+(air_temp_scat2*np.power(10*air_speed2,0.5)))/(1+np.power(10*air_speed2,0.5))
operative2_2 = operative2
plt.figure(figsize=(8,7))
#X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.05

#plt.fill_between(temperature, saturation, saturation*0.9, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.8, saturation*0.7, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.6, saturation*0.5, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.4, saturation*0.3, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.2, saturation*0.1, alpha=alph, color='k')


alph = 0.6
CS4 = plt.scatter(air_temp_scat3, operative3, c=8-comfort_scat3, marker = 'o', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)
CS5 = plt.scatter(air_temp_scat2, operative2, c=8-comfort_scat2, marker = 'o', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)
CS3 = plt.scatter(air_temp_scat, operative, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

pointwidth = 0.2

#for i in range(len(MRT_scat)):
#    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and g_scat[i] != np.nan and comfort_scat[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
#        plt.plot([air_temp_scat[i],operative[i]],[pointwidth,g_scat[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
        
#for i in range(len(MRT_scat3)):
#    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and g_scat3[i] != np.nan and comfort_scat3[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
#        plt.plot([air_temp_scat3[i],operative3[i]],[pointwidth,g_scat3[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
                          
#for i in range(len(MRT_scat2)):
#    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and g_scat2[i] != np.nan and comfort_scat2[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
#        plt.plot([air_temp_scat2[i],operative2[i]],[pointwidth,g_scat2[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)

        
#%RH lines
#plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
#plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Operative Temperature $^\circ$C",size=textsize)

thickness = 0.6
alph = 0.5
offset = .75

16.16745981
19.06545745

18.3832646255

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)

axes=plt.gca()


axes.set_ylim([20,35])
axes.set_xlim([20,35])



plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




#plt.text(21, 25, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
#plt.text(21, 23, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)
#plt.text(25.1, 1, '$T_{MRT, on} \in$ [22.6, 26.3]',size=textsize-4)
#plt.text(21,20,"$PPD_{on}=0.216$",size=textsize-4)
#plt.text(21, 18,"$PPD_{off}=0.733$",size=textsize-4)

#plt.text(26, 21, '$T_{op, on} \in$ [25.4, 29.2]',size=textsize-4)
#plt.text(29, 23, '$T_{op, off} \in$ [29.4, 32.6]',size=textsize-4)

#plt.text(27, 3.5, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25
alph = 0.5
plt.plot([25.42, 29.21], [19.5,19.5], c = 'k', alpha = alph)

plt.plot([25.42, 25.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([29.21, 29.21], [19.5-height,19.5+height], c = 'k', alpha = alph)


plt.plot([29.42, 32.63], [19.5,19.5], c = 'k', alpha = alph)

plt.plot([29.42, 29.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
plt.plot([32.63, 32.63], [19.5-height,19.5+height], c = 'k', alpha = alph)

#height = 0.125
#plt.plot([33, 33], [14.69860164,18.92509298], c = 'k', alpha = alph)
#plt.plot([33-height, 33+height], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([33-height, 33+height], [18.92509298,18.92509298], c = 'k', alpha = alph)

#plt.text(33.25, 16.5, '$\%RH$',size=textsize-4)

plt.legend(loc = 2, fontsize = textsize-6)

#plt.fill_between([22.6,26.3], [0,0], [0.25,0.25],  alpha=1, color='k')
#plt.fill_between([29.8,33.2], [0,0], [0.25,0.25], alpha=1, color='k')

plt.fill_between([10, 35], [17.5,(7/22)*35+14.32], [24.5,(7/22)*35+14.32+24.5-17.5], alpha=0.1, color='k')
plt.fill_between([10, 35], [18.5,(7/22)*35+14.32+18.5-17.5], [23.5,(7/22)*35+14.32+23.5-17.5], alpha=0.1, color='k')
axes.get_yaxis().set_visible(True)

#plt.plot([10, 35], [17.5,(7/22)*35+14.32], c = 'k', alpha = alph)
#plt.plot([10, 35], [24.5,(7/22)*35+14.32+24.5-17.5], c = 'k', alpha = alph)

#plt.plot([10, 35], [18.5,(7/22)*35+14.32+18.5-17.5], c = 'k', alpha = alph)
#plt.plot([10, 35], [23.5,(7/22)*35+14.32+23.5-17.5], c = 'k', alpha = alph)

#plt.plot([10, 35], [10,35], c = 'k', alpha = alph)


#plt.savefig("ColdTubeComfortOperative3.pdf",format='pdf')

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])
operative = (air_temp_scat+MRT_scat)/2

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)
operative3 = (air_temp_scat3+MRT_scat3)/2

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])
operative2 = (air_temp_scat2+MRT_scat2)/2

plt.figure(figsize=(8,7))
#X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.05

#plt.fill_between(temperature, saturation, saturation*0.9, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.8, saturation*0.7, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.6, saturation*0.5, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.4, saturation*0.3, alpha=alph, color='k')
#plt.fill_between(temperature, saturation*0.2, saturation*0.1, alpha=alph, color='k')


alph = 0.6
CS4 = plt.scatter(air_temp_scat3, MRT_scat3, c=8-comfort_scat3, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)
CS5 = plt.scatter(air_temp_scat2, MRT_scat2, c=8-comfort_scat2, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)
CS3 = plt.scatter(air_temp_scat, MRT_scat, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = alph)


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

pointwidth = 0.2

#for i in range(len(MRT_scat)):
#    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and g_scat[i] != np.nan and comfort_scat[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
#        plt.plot([air_temp_scat[i],operative[i]],[pointwidth,g_scat[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
        
#for i in range(len(MRT_scat3)):
#    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and g_scat3[i] != np.nan and comfort_scat3[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
#        plt.plot([air_temp_scat3[i],operative3[i]],[pointwidth,g_scat3[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)
                          
#for i in range(len(MRT_scat2)):
#    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and g_scat2[i] != np.nan and comfort_scat2[i] != 0:
#        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
#        plt.plot([air_temp_scat2[i],operative2[i]],[pointwidth,g_scat2[i]], c=colorVal,marker='o',linestyle = ':', alpha = 0.6)

        
#%RH lines
#plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
#plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Mean Radiant Temperature $^\circ$C",size=textsize)

thickness = 0.6
alph = 0.5
offset = .75

16.16745981
19.06545745

18.3832646255

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)

axes=plt.gca()


axes.set_ylim([20,35])
axes.set_xlim([20,35])



plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




#plt.text(21, 25, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
#plt.text(21, 23, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)
#plt.text(25.1, 1, '$T_{MRT, on} \in$ [22.6, 26.3]',size=textsize-4)
#plt.text(29, 26,"$PPD_{on}=0.216$",size=textsize-4)
#plt.text(29, 29,"$PPD_{off}=0.733$",size=textsize-4)

#plt.text(26, 21, '$T_{op, on} \in$ [25.4, 29.2]',size=textsize-4)
#plt.text(29, 23, '$T_{op, off} \in$ [29.4, 32.6]',size=textsize-4)

#plt.text(27, 3.5, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25
#alph = 1
#plt.plot([25.42, 29.21], [19.5,19.5], c = 'k', alpha = alph)

#plt.plot([25.42, 25.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
#plt.plot([29.21, 29.21], [19.5-height,19.5+height], c = 'k', alpha = alph)


#plt.plot([29.42, 32.63], [19.5,19.5], c = 'k', alpha = alph)

#plt.plot([29.42, 29.42], [19.5-height,19.5+height], c = 'k', alpha = alph)
#plt.plot([32.63, 32.63], [19.5-height,19.5+height], c = 'k', alpha = alph)

#height = 0.125
#plt.plot([33, 33], [14.69860164,18.92509298], c = 'k', alpha = alph)
#plt.plot([33-height, 33+height], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([33-height, 33+height], [18.92509298,18.92509298], c = 'k', alpha = alph)

#plt.text(33.25, 16.5, '$\%RH$',size=textsize-4)

plt.legend(loc = 6, fontsize = textsize-4)

#plt.fill_between([22.6,26.3], [0,0], [0.25,0.25],  alpha=1, color='k')
#plt.fill_between([29.8,33.2], [0,0], [0.25,0.25], alpha=1, color='k')

axes.get_yaxis().set_visible(True)

plt.savefig("ColdTubeComfortScatter.pdf",format='pdf')

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])
operative = (air_temp_scat+MRT_scat)/2

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)
air_speed3 = np.array(data[data['StudyID']==2]['Air Speed'].values)
operative3 = (air_temp_scat3+MRT_scat3)/2

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])
operative2 = (air_temp_scat2+MRT_scat2)/2
air_speed2 = np.array([0.5573, 0.502567, 0.277833, 0.2326, 0.194533, 0.3393, 0.272167, 0.252333, 0.366533])

plt.figure(figsize=(8,7))
#X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20



alph = 0.6
CS4 = plt.scatter(air_temp_scat3, MRT_scat3, c=8-comfort_scat3, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS5 = plt.scatter(air_temp_scat2, MRT_scat2, c=8-comfort_scat2, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS3 = plt.scatter(air_temp_scat, MRT_scat, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)


axes=plt.gca()

ymin = 20
ymax = 35
xmin = 23
xmax = 33

axes.set_ylim([ymin,ymax])
axes.set_xlim([xmin,xmax])


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

pointwidth = 0.2

speedbar_xmin = 28
speedbar_xmax = 32
speedbar_y = 27

for i in range(len(MRT_scat)):
    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and air_speed[i] != np.nan and comfort_scat[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
        plt.plot([air_temp_scat[i],air_speed[i]*(speedbar_xmax-speedbar_xmin)+speedbar_xmin],[MRT_scat[i],speedbar_y], c=colorVal,linestyle = ':', alpha = 0.6)
        
for i in range(len(MRT_scat3)):
    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and air_speed3[i] != np.nan and comfort_scat3[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
        plt.plot([air_temp_scat3[i],air_speed3[i]*(speedbar_xmax-speedbar_xmin)+speedbar_xmin],[MRT_scat3[i],speedbar_y], c=colorVal,linestyle = ':', alpha = 0.6)
                          
for i in range(len(MRT_scat2)):
    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and air_speed2[i] != np.nan and comfort_scat2[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
        plt.plot([air_temp_scat2[i],air_speed2[i]*(speedbar_xmax-speedbar_xmin)+speedbar_xmin],[MRT_scat2[i],speedbar_y], c=colorVal,linestyle = ':', alpha = 0.6)
        
        
#%RH lines
#plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
#plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Mean Radiant Temperature $^\circ$C",size=textsize)

height = 0.125
thickness = 0.6
alph = 1
offset = .75
plt.plot([speedbar_xmin, speedbar_xmax], [speedbar_y,speedbar_y], c = 'k', alpha = alph)

plt.plot([speedbar_xmin, speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)
plt.plot([speedbar_xmax, speedbar_xmax], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)

plt.plot([(speedbar_xmin+speedbar_xmax)/2,(speedbar_xmin+speedbar_xmax)/2], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)
plt.plot([(speedbar_xmax-speedbar_xmin)/4+speedbar_xmin,(speedbar_xmax-speedbar_xmin)/4+speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)
plt.plot([(speedbar_xmax-speedbar_xmin)/4*3+speedbar_xmin,(speedbar_xmax-speedbar_xmin)/4*3+speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)





plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




#plt.text(21, 25, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
#plt.text(21, 23, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)
#plt.text(25.1, 1, '$T_{MRT, on} \in$ [22.6, 26.3]',size=textsize-4)
plt.text(29, 21,"$PPD_{on}=0.216$",size=textsize-4)
plt.text(29, 34,"$PPD_{off}=0.733$",size=textsize-4)

#plt.text(26, 21, '$T_{op, on} \in$ [25.4, 29.2]',size=textsize-4)
#plt.text(29, 23, '$T_{op, off} \in$ [29.4, 32.6]',size=textsize-4)

#plt.text(27, 3.5, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25

plt.text(24.5, 26, "Air Speed ($m$ $s^{-1}$)", size=textsize)
plt.text(27.75, 27.35, "0.0", size=textsize-2)
plt.text(31.75, 27.35, "1.0", size=textsize-2)
plt.text(29.75, 27.35, "0.5", size=textsize-2)

plt.legend(loc = 2, fontsize = textsize-4)

#plt.fill_between([22.6,26.3], [0,0], [0.25,0.25],  alpha=1, color='k')
#plt.fill_between([29.8,33.2], [0,0], [0.25,0.25], alpha=1, color='k')

axes.get_yaxis().set_visible(True)




plt.savefig("ColdTubeComfortScatterAir2.pdf",format='pdf')

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.cm as cmx
#cold
air_temp_scat = np.array(data[data['StudyID']==1]['Air'].values)
g_scat = np.array((data[data['StudyID']==1]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15))/(101325*np.power((data[data['StudyID']==1]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==1]['Air']+273.15)-7235/(data[data['StudyID']==1]['Air']+273.15)))).values)
MRT_scat = np.array(data[data['StudyID']==1]['Mean Radiant Temperature'])
comfort_scat = np.array(data[data['StudyID']==1]['CTAirSat1'])
air_speed = np.array(data[data['StudyID']==1]['Air Speed'])

#warm
air_temp_scat3 = np.array(data[data['StudyID']==2]['Air'].values)
g_scat3 = np.array((data[data['StudyID']==2]['Relative Humidity']/100*1000*0.62198*np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15))/(101325*np.power((data[data['StudyID']==2]['Air']+273.15),8.2)-np.exp(77.345+0.0057*(data[data['StudyID']==2]['Air']+273.15)-7235/(data[data['StudyID']==2]['Air']+273.15)))).values)
MRT_scat3 = np.array(data[data['StudyID']==2]['Ground Truth'].values)
comfort_scat3 = np.array(data[data['StudyID']==2]['CTAirSat1'].values)

#other warm
air_temp_scat2 = np.array([30.696667, 30.983333, 29.3, 29.2, 30.693333, 29.593333, 30.71, 28.0, 30.626667])
RH2 = np.array([58.57, 59.886667, 59.516667, 60.156667, 61.76, 64.783333, 61.02, 61.166667, 59.310000])
g_scat2 = np.array((RH2/100*1000*0.62198*np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15))/(101325*np.power((air_temp_scat2+273.15),8.2)-np.exp(77.345+0.0057*(air_temp_scat2+273.15)-7235/(air_temp_scat2+273.15)))))
MRT_scat2 = np.array([32.363213, 32.411692, 30.231446, 30.010659, 31.619238, 30.590627, 31.798769, 31.130220, 31.954457])
comfort_scat2 = np.array([3, 3, 3, 3, 3, 4, 1, 3, 3])


plt.figure(figsize=(8,7))
X,Y = np.meshgrid(RH_psy_init, temp_air_init)

#set text size
textsize = 20

#set transparency
alph = 0.05

plt.fill_between(temperature, saturation, saturation*0.9, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.8, saturation*0.7, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.6, saturation*0.5, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.4, saturation*0.3, alpha=alph, color='k')
plt.fill_between(temperature, saturation*0.2, saturation*0.1, alpha=alph, color='k')


alph = 0.6
CS4 = plt.scatter(air_temp_scat3, g_scat3, c=8-comfort_scat3, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS5 = plt.scatter(air_temp_scat2, g_scat2, c=8-comfort_scat2, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)
CS3 = plt.scatter(air_temp_scat, g_scat, c=8-comfort_scat, marker = 's', s=50, cmap=cm.coolwarm, norm = mpl.colors.Normalize(vmin=np.amin(1),vmax=np.amax(7)), alpha = 1)


jet = cm = plt.get_cmap('coolwarm') 
cNorm  = colors.Normalize(vmin=1, vmax=7)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
height = 0.25
speedbar_xmin = 25
speedbar_xmax = 34
speedbar_y = 7

plt.plot([speedbar_xmin, speedbar_xmax], [speedbar_y,speedbar_y], c = 'k', alpha = alph)

plt.plot([speedbar_xmin, speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)
plt.plot([speedbar_xmax, speedbar_xmax], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = alph)

plt.plot([(speedbar_xmin+speedbar_xmax)/2,(speedbar_xmin+speedbar_xmax)/2], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = 1)

plt.plot([(speedbar_xmax-speedbar_xmin)/4+speedbar_xmin,(speedbar_xmax-speedbar_xmin)/4+speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = 1)
plt.plot([(speedbar_xmax-speedbar_xmin)/4*3+speedbar_xmin,(speedbar_xmax-speedbar_xmin)/4*3+speedbar_xmin], [speedbar_y-height,speedbar_y+height], c = 'k', alpha = 1)



for i in range(len(MRT_scat)):
    if MRT_scat[i]!=np.nan and air_temp_scat[i] != np.nan and g_scat[i] != np.nan and comfort_scat[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat[i])
        plt.plot([((MRT_scat[i]-22.6)/(33.2-22.6))*(speedbar_xmax-speedbar_xmin)+speedbar_xmin,air_temp_scat[i]],[speedbar_y,g_scat[i]], c=colorVal,linestyle = ':', alpha = 0.6)
        
for i in range(len(MRT_scat3)):
    if MRT_scat3[i]!=np.nan and air_temp_scat3[i] != np.nan and g_scat3[i] != np.nan and comfort_scat3[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat3[i])
        plt.plot([((MRT_scat3[i]-22.6)/(33.2-22.6))*(speedbar_xmax-speedbar_xmin)+speedbar_xmin,air_temp_scat3[i]],[speedbar_y,g_scat3[i]], c=colorVal,linestyle = ':', alpha = 0.6)
                          
for i in range(len(MRT_scat2)):
    if MRT_scat2[i]!=np.nan and air_temp_scat2[i] != np.nan and g_scat2[i] != np.nan and comfort_scat2[i] != 0:
        colorVal = scalarMap.to_rgba(8-comfort_scat2[i])
        plt.plot([((MRT_scat2[i]-22.6)/(33.2-22.6))*(speedbar_xmax-speedbar_xmin)+speedbar_xmin,air_temp_scat2[i]],[speedbar_y,g_scat2[i]], c=colorVal,linestyle = ':', alpha = 0.6)

        
#%RH lines
plt.text(32.75, 3, '10 $\%RH$',size=textsize-4)
plt.text(28, 25.1, '100 $\%RH$',size=textsize-4)


plt.xlabel("Air Temperature $^\circ$C", size=textsize)
plt.ylabel("Humidity Ratio (g water/kg dry air)",size=textsize)

thickness = 0.6
alph = 0.5
offset = .75

16.16745981
19.06545745

18.3832646255

#plt.plot([28-offset, 31.8], [16.16745981,16.16745981], c = 'k', alpha = alph)
#plt.plot([28, 28], [16.16745981-offset,18.3832646255], c = 'k', alpha = alph)

#plt.plot([28.0, 31.96+offset], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([31.96, 31.96], [14.69860164-offset,17.1], c = 'k', alpha = alph)

axes=plt.gca()


axes.set_ylim([0,28])
axes.set_xlim([20,35])



plt.tick_params(axis='both', labelsize=textsize)
#cbar.ax.tick_params(labelsize=textsize) 
#plt.axis('off')
axes.get_xaxis().set_visible(True)




#plt.text(28, 23, '$T_{air, on} \in$ [28.0, 31.8]',size=textsize-4)
#plt.text(28, 21, '$T_{air, off} \in$ [28.0, 32.0]',size=textsize-4)
#plt.text(26.5, 19.3, '$\%RH \in$ [56.3, 76.5]',size=textsize-4)


plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(1), marker = "s", linestyle = 'None', label = 'Very Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(2), marker = "s", linestyle = 'None', label = 'Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(3), marker = "s", linestyle = 'None', label = 'Somewhat Satisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(4), marker = "s", linestyle = 'None', label = 'Neutral')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(5), marker = "s", linestyle = 'None', label = 'Somewhat Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(6), marker = "s", linestyle = 'None', label = 'Dissatisfied')
plt.plot([22,22],[-10,-10], color = scalarMap.to_rgba(7), marker = "s", linestyle = 'None', label = 'Very Dissatisfied')

height = 0.25
alph = 1
#plt.plot([28, 32.0], [19.5,19.5], c = 'k', alpha = alph)

#plt.plot([28, 28], [19.5-height,19.5+height], c = 'k', alpha = alph)
#plt.plot([31.8, 31.8], [19.5-height,19.5+height], c = 'k', alpha = alph)
#plt.plot([32.0, 32.0], [19.5-height,19.5+height], c = 'k', alpha = alph)

height = 0.125
#plt.plot([32.5, 32.5], [14.69860164,18.92509298], c = 'k', alpha = alph)
#plt.plot([32.5-height, 32.5+height], [14.69860164,14.69860164], c = 'k', alpha = alph)
#plt.plot([32.5-height, 32.5+height], [18.92509298,18.92509298], c = 'k', alpha = alph)

#plt.text(32.75, 16.5, '$\%RH$',size=textsize-4)

plt.legend(loc = 2, fontsize = textsize-4)

plt.text(21.1, 11, '$T_{MRT, on} \in$ [22.6, 26.5]',size=textsize-4)
plt.text(21.1, 9,"$PPD_{on}=0.216$",size=textsize-4)


plt.text(29, 22,"$PPD_{off}=0.733$",size=textsize-4)
plt.text(29, 20, '$T_{MRT, off} \in$ [29.8, 33.2]',size=textsize-4)

plt.text(27.75, 3.5,"$T_{MRT}$ ($^\circ C$)",size=textsize)
plt.text(24.5, 5.25,"22.6",size=textsize-4)
plt.text(33.5, 5.25,"33.2",size=textsize-4)
plt.text(29, 5.25,"27.9",size=textsize-4)

plt.text(26.75, 5.25,"25.5",size=textsize-4)
plt.text(31.25, 5.25,"30.1",size=textsize-4)

axes.get_yaxis().set_visible(True)

plt.savefig("ColdTubeComfortCombined2.pdf",format='pdf')
